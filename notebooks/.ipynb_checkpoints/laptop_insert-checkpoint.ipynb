# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\luisa\\Documents\\NORRDATA\\proyectos\\dogdaycare\\notebooks'

# %%
payments = pd.read_csv("../data/clean/payments_clean.csv")
len(payments)
# Out:
# 1344

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:admin123@localhost:5432/dogdaycare")

# %%
payments.to_sql(
    "payments",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 344
